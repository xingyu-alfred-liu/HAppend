# %% [markdown]
# ## Guide
# In this tutorial, you can learn how to load all data into one dictionary, plot bandstructure and absorption from PAH101 dataset.

# %%
# Load packages
from pah101tools.plot import PlotAgent

# %% [markdown]
# ### Load dataset
# To gather all data, you will need to specify the path point to the data folder. After plot_agent is setup, you can access all data through `plot_agent.data_dict`

# %%
root_path = "/Users/alfred/Desktop/work/PAH101/PAH101Plot/data"
plot_agent = PlotAgent(root_path=root_path)

print(plot_agent.data_dict.keys())
# Out:
# dict_keys(['CEQGEL', 'DUPHAX', 'QUPHEN01', 'VEBJOC', 'PEZPUG', 'CARREU', 'KAGGEG', 'TPHBEN01', 'KECLAH', 'KAQLEV', 'BZPHAN', 'VEBJIW', 'YUNYAJ', 'KUZXUA', 'PEZPIU', 'DBPHEN02', 'SANQII', 'CORXAI10', 'ZZZOYC01', 'DBNTHR02', 'OVALEN01', 'VEBKAP', 'BNPYRE10', 'KEGHEJ01', 'REBWIE', 'PUNVIE', 'QUATER10', 'QQQCIG14', 'FLUANT02', 'RAKGOA', 'DPANTR01', 'PHNAPH', 'TBZPYR', 'BENZEN', 'QQQCIG13', 'PERLEN07', 'BIGJUX', 'TBZPER', 'PUNVEA', 'CORONE01', 'PYRCEN', 'LIMCUF', 'TEBNAP', 'OBOHUL', 'BIPHEN', 'POBPIG06', 'VEBJES', 'TETCEN01', 'YOFCUR', 'YITJAN', 'QQQCIG04', 'PUJQIV', 'NAPANT01', 'VEHCAM', 'KAGFOP', 'ABECAL', 'PERLEN05', 'KAGFUV', 'ZZZNTQ01', 'SETTES', 'FOVVOB', 'GUQZUP', 'KAFVUI', 'SURTAA', 'VUFHUA', 'IZUCIP', 'TAYSUJ', 'TERPHO02', 'BNPERY', 'BIFUOR', 'KAGGAC', 'TBZHCE', 'BOXGAW', 'JULSOY', 'CRYSEN01', 'POBPIG', 'DBZCOR', 'ZZZNKU01', 'FACPEE', 'ANTCEN', 'PENCEN', 'CENYAV', 'PYRPYR10', 'KUBWAF01', 'ZZZDKE01', 'HPHBNZ03', 'QUPHEN', 'XECJIZ', 'DNAPAN', 'KUBVUY', 'BEANTR', 'KAGGIK', 'HBZCOR', 'CENYEZ', 'KIDJUD03', 'CENXUO', 'TRIPHE12', 'VEBJAO', 'CORANN12', 'DBPERY', 'TERPHE02'])

# %% [markdown]
# ### Plot Bandstructure
# Pass in the `struct_id`, and `savefig_path` to specify which material to plot bandstructure for, and where to save the plot. If `savefig_path` is not specified, the plot will NOT be saved. Here we use "ABECAL" and "band.png" as an example. Similar for absorption.

# %%
struct_id = "ABECAL"
savefig_path = "band.png"

bandstruct_fig = plot_agent.plot_bandstructure(
    struct_id=struct_id, 
    savefig_path=savefig_path
)

bandstruct_fig.show()
# Out:
# The high symmetry points are: ['##Gamma', '##Z', '##D', '##B', '##Gamma', '##A', '##E', '##Z', '##C2', '##Y2', '##Gamma']
# The invervals between each pair of points are: [10, 5, 10, 5, 7, 7, 7, 5, 8, 5]
# The shift index are: []
# The kpoint index are: [0, 11, 17, 28, 34, 42, 50, 58, 64, 73, 79]
# The kpoint names to be printed are: ['##Gamma', '##Z', '##D', '##B', '##Gamma', '##A', '##E', '##Z', '##C2', '##Y2', '##Gamma']
# bandgap is: 2.697075611 eV
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# name ##Gamma
# name ##Z
# name ##D
# name ##B
# name ##Gamma
# name ##A
# name ##E
# name ##Z
# name ##C2
# name ##Y2
# name ##Gamma
# ['$\\Gamma$', '$Z$', '$D$', '$B$', '$\\Gamma$', '$A$', '$E$', '$Z$', '$C2$', '$Y2$', '$\\Gamma$']
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-a85c32f28c9b> in <module>
#       7 )
#       8
# ----> 9 bandstruct_fig.show()
#
# AttributeError: 'NoneType' object has no attribute 'show'
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.
# findfont: Font family 'Helvatica' not found.

# %% [markdown]
# ### Plot Absorption

# %%
struct_id = "ABECAL"
savefig_path = "absorp.png"

absorption_fig = plot_agent.plot_absorption(
    struct_id=struct_id,
    savefig_path=savefig_path
)

absorption_fig.show()
